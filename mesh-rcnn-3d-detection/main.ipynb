# %%
import torch
import sys
import platform

print("Python:", sys.version)
print("Platform:", platform.platform())
print("PyTorch:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# Python: 3.10.12 (main, Mar  3 2026, 11:56:32) [GCC 11.4.0]
# Platform: Linux-5.15.167.4-microsoft-standard-WSL2-x86_64-with-glibc2.35
# PyTorch: 2.1.2+cu121
# CUDA available: True
# GPU: NVIDIA GeForce RTX 3050 Laptop GPU

# %%
import torch
import detectron2
import pytorch3d

print("torch:", torch.__version__)
print("detectron2 imported successfully")
print("pytorch3d imported successfully")
# Out:
# torch: 2.1.2+cu121
# detectron2 imported successfully
# pytorch3d imported successfully

# %%
from pathlib import Path

BASE_DIR = Path.home() / "Assign_6"
MESHRCNN_DIR = BASE_DIR / "meshrcnn"

IMG_DIR = BASE_DIR / "input_images"
OUT_DIR = BASE_DIR / "outputs"
RENDER_DIR = BASE_DIR / "renders"

IMG_DIR.mkdir(parents=True, exist_ok=True)
OUT_DIR.mkdir(parents=True, exist_ok=True)
RENDER_DIR.mkdir(parents=True, exist_ok=True)

print("Base:", BASE_DIR)
print("Mesh R-CNN:", MESHRCNN_DIR)
print("Images:", IMG_DIR)
print("Outputs:", OUT_DIR)
print("Renders:", RENDER_DIR)
# Out:
# Base: /home/mad03633/Assign_6
# Mesh R-CNN: /home/mad03633/Assign_6/meshrcnn
# Images: /home/mad03633/Assign_6/input_images
# Outputs: /home/mad03633/Assign_6/outputs
# Renders: /home/mad03633/Assign_6/renders

# %%
# Image paths
image_paths = {
    "chair_pix3d": IMG_DIR / "chair.jpg",
    "sofa_pix3d": IMG_DIR / "sofa.jpg",
    "motorcycle_ood": IMG_DIR / "motorcycle.jpg",
}

for name, path in image_paths.items():
    print(name, "->", path, "| exists:", path.exists())
# Out:
# chair_pix3d -> /home/mad03633/Assign_6/input_images/chair.jpg | exists: True
# sofa_pix3d -> /home/mad03633/Assign_6/input_images/sofa.jpg | exists: True
# motorcycle_ood -> /home/mad03633/Assign_6/input_images/motorcycle.jpg | exists: True

# %%
# Display images
import matplotlib.pyplot as plt
from PIL import Image

plt.figure(figsize=(16, 5))

for i, (name, path) in enumerate(image_paths.items(), 1):
    plt.subplot(1, 3, i)
    
    if path.exists():
        img = Image.open(path).convert("RGB")
        plt.imshow(img)
        plt.title(name)
    else:
        plt.text(0.5, 0.5, f"{name}\nnot found", ha="center", va="center")
    
    plt.axis("off")

plt.tight_layout()
plt.show()

# %%
# Run Mesh R-CNN demo for chair
import sys

# %cd /home/mad03633/Assign_6/meshrcnn

# !PYTHONPATH=/home/mad03633/Assign_6/meshrcnn {sys.executable} demo/demo.py \
    --config-file configs/pix3d/meshrcnn_R50_FPN.yaml \
    --input /home/mad03633/Assign_6/input_images/chair.jpg \
    --output /home/mad03633/Assign_6/outputs/chair \
    --onlyhighest \
    MODEL.WEIGHTS meshrcnn://meshrcnn_R50.pth
# Out:
# /home/mad03633/Assign_6/meshrcnn
# /home/mad03633/Assign_6/graphics/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# [04/29 19:08:18 demo]: Arguments: Namespace(config_file='configs/pix3d/meshrcnn_R50_FPN.yaml', input='/home/mad03633/Assign_6/input_images/chair.jpg', output='/home/mad03633/Assign_6/outputs/chair', focal_length=20.0, onlyhighest=True, opts=['MODEL.WEIGHTS', 'meshrcnn://meshrcnn_R50.pth'])
# /home/mad03633/Assign_6/graphics/lib/python3.10/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3526.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# [04/29 19:08:22 demo]: Predictions saved in /home/mad03633/Assign_6/outputs/chair/chair

# %%
# Run Mesh R-CNN demo for sofa
import sys

# %cd /home/mad03633/Assign_6/meshrcnn

# !PYTHONPATH=/home/mad03633/Assign_6/meshrcnn {sys.executable} demo/demo.py \
    --config-file configs/pix3d/meshrcnn_R50_FPN.yaml \
    --input /home/mad03633/Assign_6/input_images/sofa.jpg \
    --output /home/mad03633/Assign_6/outputs/sofa \
    --onlyhighest \
    MODEL.WEIGHTS meshrcnn://meshrcnn_R50.pth
# Out:
# /home/mad03633/Assign_6/meshrcnn
# [04/29 19:08:33 demo]: Arguments: Namespace(config_file='configs/pix3d/meshrcnn_R50_FPN.yaml', input='/home/mad03633/Assign_6/input_images/sofa.jpg', output='/home/mad03633/Assign_6/outputs/sofa', focal_length=20.0, onlyhighest=True, opts=['MODEL.WEIGHTS', 'meshrcnn://meshrcnn_R50.pth'])
# /home/mad03633/Assign_6/graphics/lib/python3.10/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3526.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# [04/29 19:08:37 demo]: Predictions saved in /home/mad03633/Assign_6/outputs/sofa/sofa

# %%
# Run Mesh R-CNN demo for motorcycle
import sys

# %cd /home/mad03633/Assign_6/meshrcnn

# !PYTHONPATH=/home/mad03633/Assign_6/meshrcnn {sys.executable} demo/demo.py \
    --config-file configs/pix3d/meshrcnn_R50_FPN.yaml \
    --input /home/mad03633/Assign_6/input_images/motorcycle.jpg \
    --output /home/mad03633/Assign_6/outputs/motorcycle \
    MODEL.WEIGHTS meshrcnn://meshrcnn_R50.pth
# Out:
# /home/mad03633/Assign_6/meshrcnn
# [04/29 19:08:43 demo]: Arguments: Namespace(config_file='configs/pix3d/meshrcnn_R50_FPN.yaml', input='/home/mad03633/Assign_6/input_images/motorcycle.jpg', output='/home/mad03633/Assign_6/outputs/motorcycle', focal_length=20.0, onlyhighest=False, opts=['MODEL.WEIGHTS', 'meshrcnn://meshrcnn_R50.pth'])
# /home/mad03633/Assign_6/graphics/lib/python3.10/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3526.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# [04/29 19:08:49 demo]: Predictions saved in /home/mad03633/Assign_6/outputs/motorcycle/motorcycle

# %%
from pathlib import Path


# Results overview
for folder_name in ["chair", "sofa", "motorcycle"]:
    folder = OUT_DIR / folder_name
    
    print("\n" + "=" * 60)
    print(folder_name)
    print("=" * 60)
    
    if folder.exists():
        files = sorted(folder.rglob("*"))
        if len(files) == 0:
            print("Folder is empty")
        else:
            for file in files:
                print(file.relative_to(BASE_DIR))
    else:
        print("Folder does not exist:", folder)
# Out:
# ============================================================
# chair
# ============================================================
# outputs/chair/chair
# outputs/chair/chair/0_mask_chair_1.000.png
# outputs/chair/chair/0_mesh_chair_1.000.obj
#
# ============================================================
# sofa
# ============================================================
# outputs/sofa/sofa
# outputs/sofa/sofa/0_mask_sofa_1.000.png
# outputs/sofa/sofa/0_mesh_sofa_1.000.obj
#
# ============================================================
# motorcycle
# ============================================================
# outputs/motorcycle/motorcycle
# outputs/motorcycle/motorcycle/0_mask_chair_0.989.png
# outputs/motorcycle/motorcycle/0_mesh_chair_0.989.obj
# outputs/motorcycle/motorcycle/10_mask_tool_0.149.png
# outputs/motorcycle/motorcycle/10_mesh_tool_0.149.obj
# outputs/motorcycle/motorcycle/11_mask_desk_0.148.png
# outputs/motorcycle/motorcycle/11_mesh_desk_0.148.obj
# outputs/motorcycle/motorcycle/12_mask_chair_0.144.png
# outputs/motorcycle/motorcycle/12_mesh_chair_0.144.obj
# outputs/motorcycle/motorcycle/13_mask_tool_0.121.png
# outputs/motorcycle/motorcycle/13_mesh_tool_0.121.obj
# outputs/motorcycle/motorcycle/14_mask_chair_0.115.png
# outputs/motorcycle/motorcycle/14_mesh_chair_0.115.obj
# outputs/motorcycle/motorcycle/15_mask_chair_0.109.png
# outputs/motorcycle/motorcycle/15_mesh_chair_0.109.obj
# outputs/motorcycle/motorcycle/16_mask_misc_0.100.png
# outputs/motorcycle/motorcycle/16_mesh_misc_0.100.obj
# outputs/motorcycle/motorcycle/17_mask_desk_0.096.png
# outputs/motorcycle/motorcycle/17_mesh_desk_0.096.obj
# outputs/motorcycle/motorcycle/18_mask_misc_0.084.png
# outputs/motorcycle/motorcycle/18_mesh_misc_0.084.obj
# outputs/motorcycle/motorcycle/19_mask_misc_0.067.png
# outputs/motorcycle/motorcycle/19_mesh_misc_0.067.obj
# outputs/motorcycle/motorcycle/1_mask_bed_0.749.png
# outputs/motorcycle/motorcycle/1_mesh_bed_0.749.obj
# outputs/motorcycle/motorcycle/20_mask_tool_0.066.png
# outputs/motorcycle/motorcycle/20_mesh_tool_0.066.obj
# outputs/motorcycle/motorcycle/21_mask_bookcase_0.056.png
# outputs/motorcycle/motorcycle/21_mesh_bookcase_0.056.obj
# outputs/motorcycle/motorcycle/2_mask_table_0.724.png
# outputs/motorcycle/motorcycle/2_mesh_table_0.724.obj
# outputs/motorcycle/motorcycle/3_mask_table_0.589.png
# outputs/motorcycle/motorcycle/3_mesh_table_0.589.obj
# outputs/motorcycle/motorcycle/4_mask_sofa_0.436.png
# outputs/motorcycle/motorcycle/4_mesh_sofa_0.436.obj
# outputs/motorcycle/motorcycle/5_mask_tool_0.415.png
# outputs/motorcycle/motorcycle/5_mesh_tool_0.415.obj
# outputs/motorcycle/motorcycle/6_mask_tool_0.336.png
# outputs/motorcycle/motorcycle/6_mesh_tool_0.336.obj
# outputs/motorcycle/motorcycle/7_mask_tool_0.305.png
# outputs/motorcycle/motorcycle/7_mesh_tool_0.305.obj
# outputs/motorcycle/motorcycle/8_mask_chair_0.280.png
# outputs/motorcycle/motorcycle/8_mesh_chair_0.280.obj
# outputs/motorcycle/motorcycle/9_mask_sofa_0.204.png
# outputs/motorcycle/motorcycle/9_mesh_sofa_0.204.obj

# %%
# Search for OBJ files in outputs
from pathlib import Path


def find_obj_files(folder):
    folder = Path(folder)
    return sorted(folder.rglob("*.obj"))

mesh_files = {}

for name in ["chair", "sofa", "motorcycle"]:
    objs = find_obj_files(OUT_DIR / name)
    mesh_files[name] = objs
    
    print("\n" + "=" * 60)
    print(name)
    print("=" * 60)
    
    if len(objs) == 0:
        print("No OBJ files found")
    else:
        for obj in objs:
            print(obj.relative_to(BASE_DIR))
# Out:
# ============================================================
# chair
# ============================================================
# outputs/chair/chair/0_mesh_chair_1.000.obj
#
# ============================================================
# sofa
# ============================================================
# outputs/sofa/sofa/0_mesh_sofa_1.000.obj
#
# ============================================================
# motorcycle
# ============================================================
# outputs/motorcycle/motorcycle/0_mesh_chair_0.989.obj
# outputs/motorcycle/motorcycle/10_mesh_tool_0.149.obj
# outputs/motorcycle/motorcycle/11_mesh_desk_0.148.obj
# outputs/motorcycle/motorcycle/12_mesh_chair_0.144.obj
# outputs/motorcycle/motorcycle/13_mesh_tool_0.121.obj
# outputs/motorcycle/motorcycle/14_mesh_chair_0.115.obj
# outputs/motorcycle/motorcycle/15_mesh_chair_0.109.obj
# outputs/motorcycle/motorcycle/16_mesh_misc_0.100.obj
# outputs/motorcycle/motorcycle/17_mesh_desk_0.096.obj
# outputs/motorcycle/motorcycle/18_mesh_misc_0.084.obj
# outputs/motorcycle/motorcycle/19_mesh_misc_0.067.obj
# outputs/motorcycle/motorcycle/1_mesh_bed_0.749.obj
# outputs/motorcycle/motorcycle/20_mesh_tool_0.066.obj
# outputs/motorcycle/motorcycle/21_mesh_bookcase_0.056.obj
# outputs/motorcycle/motorcycle/2_mesh_table_0.724.obj
# outputs/motorcycle/motorcycle/3_mesh_table_0.589.obj
# outputs/motorcycle/motorcycle/4_mesh_sofa_0.436.obj
# outputs/motorcycle/motorcycle/5_mesh_tool_0.415.obj
# outputs/motorcycle/motorcycle/6_mesh_tool_0.336.obj
# outputs/motorcycle/motorcycle/7_mesh_tool_0.305.obj
# outputs/motorcycle/motorcycle/8_mesh_chair_0.280.obj
# outputs/motorcycle/motorcycle/9_mesh_sofa_0.204.obj

# %%
import re
import pandas as pd

# Extract confidence score from filename
def extract_confidence_from_filename(path):
    """
    Tries to extract confidence score from filename.
    Example:
    0_mesh_sofa_0.887.obj -> 0.887
    """
    name = Path(path).stem
    numbers = re.findall(r"\d+\.\d+", name)
    
    if len(numbers) == 0:
        return None
    
    return float(numbers[-1])

# Extract predicted class from filename
def extract_class_from_filename(path):
    """
    Example:
    0_mesh_chair_1.000.obj -> chair
    1_mesh_bed_0.749.obj -> bed
    """
    name = Path(path).stem
    
    # remove index and prefix
    # 0_mesh_chair_1.000 -> chair
    parts = name.split("_")
    
    if len(parts) >= 4:
        return "_".join(parts[2:-1])
    
    return None

records = []

for image_name, objs in mesh_files.items():
    for obj in objs:
        records.append({
            "input_image": image_name,
            "predicted_class": extract_class_from_filename(obj),
            "mesh_file": obj.name,
            "full_path": str(obj),
            "confidence_score": extract_confidence_from_filename(obj)
        })

df_meshes = pd.DataFrame(records)

print("Rows:", len(df_meshes))
display(df_meshes)
# Out:
# Rows: 24
#    input_image predicted_class                   mesh_file  \
# 0        chair           chair      0_mesh_chair_1.000.obj
# 1         sofa            sofa       0_mesh_sofa_1.000.obj
# 2   motorcycle           chair      0_mesh_chair_0.989.obj
# 3   motorcycle            tool      10_mesh_tool_0.149.obj
# 4   motorcycle            desk      11_mesh_desk_0.148.obj
# 5   motorcycle           chair     12_mesh_chair_0.144.obj
# 6   motorcycle            tool      13_mesh_tool_0.121.obj
# 7   motorcycle           chair     14_mesh_chair_0.115.obj
# 8   motorcycle           chair     15_mesh_chair_0.109.obj
# 9   motorcycle            misc      16_mesh_misc_0.100.obj
# 10  motorcycle            desk      17_mesh_desk_0.096.obj
# 11  motorcycle            misc      18_mesh_misc_0.084.obj
# 12  motorcycle            misc      19_mesh_misc_0.067.obj
# 13  motorcycle             bed        1_mesh_bed_0.749.obj
# 14  motorcycle            tool      20_mesh_tool_0.066.obj
# 15  motorcycle        bookcase  21_mesh_bookcase_0.056.obj
# 16  motorcycle           table      2_mesh_table_0.724.obj
# 17  motorcycle           table      3_mesh_table_0.589.obj
# 18  motorcycle            sofa       4_mesh_sofa_0.436.obj
# 19  motorcycle            tool       5_mesh_tool_0.415.obj
# 20  motorcycle            tool       6_mesh_tool_0.336.obj
# 21  motorcycle            tool       7_mesh_tool_0.305.obj
# 22  motorcycle           chair      8_mesh_chair_0.280.obj
# 23  motorcycle            sofa       9_mesh_sofa_0.204.obj
#
#                                             full_path  confidence_score
# 0   /home/mad03633/Assign_6/outputs/chair/chair/0_...             1.000
# 1   /home/mad03633/Assign_6/outputs/sofa/sofa/0_me...             1.000
# 2   /home/mad03633/Assign_6/outputs/motorcycle/mot...             0.989
# 3   /home/mad03633/Assign_6/outputs/motorcycle/mot...             0.149
# 4   /home/mad03633/Assign_6/outputs/motorcycle/mot...             0.148
# 5   /home/mad03633/Assign_6/outputs/motorcycle/mot...             0.144
# 6   /home/mad03633/Assign_6/outputs/motorcycle/mot...             0.121
# 7   /home/mad03633/Assign_6/outputs/motorcycle/mot...             0.115
# 8   /home/mad03633/Assign_6/outputs/motorcycle/mot...             0.109
# 9   /home/mad03633/Assign_6/outputs/motorcycle/mot...             0.100
# 10  /home/mad03633/Assign_6/outputs/motorcycle/mot...             0.096
# 11  /home/mad03633/Assign_6/outputs/motorcycle/mot...             0.084
# 12  /home/mad03633/Assign_6/outputs/motorcycle/mot...             0.067
# 13  /home/mad03633/Assign_6/outputs/motorcycle/mot...             0.749
# 14  /home/mad03633/Assign_6/outputs/motorcycle/mot...             0.066
# 15  /home/mad03633/Assign_6/outputs/motorcycle/mot...             0.056
# 16  /home/mad03633/Assign_6/outputs/motorcycle/mot...             0.724
# 17  /home/mad03633/Assign_6/outputs/motorcycle/mot...             0.589
# 18  /home/mad03633/Assign_6/outputs/motorcycle/mot...             0.436
# 19  /home/mad03633/Assign_6/outputs/motorcycle/mot...             0.415
# 20  /home/mad03633/Assign_6/outputs/motorcycle/mot...             0.336
# 21  /home/mad03633/Assign_6/outputs/motorcycle/mot...             0.305
# 22  /home/mad03633/Assign_6/outputs/motorcycle/mot...             0.280
# 23  /home/mad03633/Assign_6/outputs/motorcycle/mot...             0.204

# %%
# Top-1 mesh per image based on confidence score
df_top = (
    df_meshes
    .sort_values(["input_image", "confidence_score"], ascending=[True, False])
    .groupby("input_image")
    .head(1)
    .reset_index(drop=True)
)

display(df_top)
# Out:
#   input_image predicted_class               mesh_file  \
# 0       chair           chair  0_mesh_chair_1.000.obj
# 1  motorcycle           chair  0_mesh_chair_0.989.obj
# 2        sofa            sofa   0_mesh_sofa_1.000.obj
#
#                                            full_path  confidence_score
# 0  /home/mad03633/Assign_6/outputs/chair/chair/0_...             1.000
# 1  /home/mad03633/Assign_6/outputs/motorcycle/mot...             0.989
# 2  /home/mad03633/Assign_6/outputs/sofa/sofa/0_me...             1.000

# %%
import matplotlib.pyplot as plt
from PIL import Image


# Function to display output images
def show_output_images(folder, title):
    folder = Path(folder)
    image_files = (
        list(folder.rglob("*.png")) +
        list(folder.rglob("*.jpg")) +
        list(folder.rglob("*.jpeg"))
    )
    
    if len(image_files) == 0:
        print("No output images found in:", folder)
        return
    
    plt.figure(figsize=(5 * min(len(image_files), 4), 5))
    
    for i, img_path in enumerate(image_files[:4], 1):
        img = Image.open(img_path).convert("RGB")
        plt.subplot(1, min(len(image_files), 4), i)
        plt.imshow(img)
        plt.title(img_path.name)
        plt.axis("off")
    
    plt.suptitle(title)
    plt.tight_layout()
    plt.show()

show_output_images(OUT_DIR / "chair", "Mesh R-CNN output: chair")
show_output_images(OUT_DIR / "sofa", "Mesh R-CNN output: sofa")
show_output_images(OUT_DIR / "motorcycle", "Mesh R-CNN output: motorcycle")

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("Device:", device)
# Out:
# Device: cuda:0

# %%
from pytorch3d.io import load_obj
from pytorch3d.structures import Meshes
from pytorch3d.renderer import TexturesVertex


# Function of mesh loading for rendering
def load_mesh_for_rendering(obj_path):
    obj_path = Path(obj_path)
    
    verts, faces_idx, _ = load_obj(str(obj_path))
    faces = faces_idx.verts_idx
    
    # Center and normalize mesh
    center = verts.mean(dim=0)
    verts = verts - center
    
    scale = verts.abs().max()
    if scale > 0:
        verts = verts / scale
    
    verts = verts.to(device)
    faces = faces.to(device)
    
    # White vertex texture
    verts_rgb = torch.ones_like(verts)[None].to(device)
    textures = TexturesVertex(verts_features=verts_rgb)
    
    mesh = Meshes(
        verts=[verts],
        faces=[faces],
        textures=textures
    )
    
    return mesh

# %%
from pytorch3d.renderer.cameras import FoVPerspectiveCameras
from pytorch3d.renderer import (
    RasterizationSettings,
    MeshRenderer,
    MeshRasterizer,
    HardPhongShader,
    PointLights,
    look_at_view_transform
)


# 3-view mesh rendering function
def render_mesh_views(
    obj_path,
    save_prefix,
    distance=3.0,
    elevations=(10, 20, 30),
    azimuths=(-60, 0, 60),
    image_size=512
):
    obj_path = Path(obj_path)
    mesh = load_mesh_for_rendering(obj_path)
    
    raster_settings = RasterizationSettings(
        image_size=image_size,
        blur_radius=0.0,
        faces_per_pixel=1,
    )
    
    lights = PointLights(
        device=device,
        location=((2.0, 2.0, 2.0),)
    )
    
    rendered_images = []
    
    for idx, (elev, azim) in enumerate(zip(elevations, azimuths), 1):
        R, T = look_at_view_transform(
            dist=distance,
            elev=elev,
            azim=azim,
            device=device
        )
        
        cameras = FoVPerspectiveCameras(device=device, R=R, T=T)
        
        renderer = MeshRenderer(
            rasterizer=MeshRasterizer(
                cameras=cameras,
                raster_settings=raster_settings
            ),
            shader=HardPhongShader(
                device=device,
                cameras=cameras,
                lights=lights
            )
        )
        
        image = renderer(mesh)
        image_np = image[0, ..., :3].detach().cpu().numpy()
        rendered_images.append((elev, azim, image_np))
        
        save_path = RENDER_DIR / f"{save_prefix}_view{idx}_elev{elev}_azim{azim}.png"
        plt.imsave(save_path, image_np)
        print("Saved:", save_path)
    
    plt.figure(figsize=(15, 5))
    
    for i, (elev, azim, img) in enumerate(rendered_images, 1):
        plt.subplot(1, len(rendered_images), i)
        plt.imshow(img)
        plt.title(f"elev={elev}, azim={azim}")
        plt.axis("off")
    
    plt.suptitle(save_prefix)
    plt.tight_layout()
    plt.show()

# %%
# Select the main mesh for each image
def get_top_mesh(input_image_name):
    subset = df_meshes[df_meshes["input_image"] == input_image_name].copy()
    
    if len(subset) == 0:
        return None
    
    subset = subset.sort_values("confidence_score", ascending=False)
    return Path(subset.iloc[0]["full_path"])

chair_mesh = get_top_mesh("chair")
sofa_mesh = get_top_mesh("sofa")
motorcycle_mesh = get_top_mesh("motorcycle")

print("Chair mesh:", chair_mesh)
print("Sofa mesh:", sofa_mesh)
print("Motorcycle mesh:", motorcycle_mesh)
# Out:
# Chair mesh: /home/mad03633/Assign_6/outputs/chair/chair/0_mesh_chair_1.000.obj
# Sofa mesh: /home/mad03633/Assign_6/outputs/sofa/sofa/0_mesh_sofa_1.000.obj
# Motorcycle mesh: /home/mad03633/Assign_6/outputs/motorcycle/motorcycle/0_mesh_chair_0.989.obj

# %%
# Render chair mesh views
if chair_mesh is not None:
    render_mesh_views(
        obj_path=chair_mesh,
        save_prefix="chair",
        distance=2.0,
        elevations=(10, 20, 30),
        azimuths=(-60, 0, 60)
    )
else:
    print("No mesh found for chair")
# Out:
# /home/mad03633/Assign_6/graphics/lib/python3.10/site-packages/pytorch3d/io/obj_io.py:544: UserWarning: No mtl file provided
#   warnings.warn("No mtl file provided")
# Saved: /home/mad03633/Assign_6/renders/chair_view1_elev10_azim-60.png
# Saved: /home/mad03633/Assign_6/renders/chair_view2_elev20_azim0.png
# Saved: /home/mad03633/Assign_6/renders/chair_view3_elev30_azim60.png

# %%
# Render sofa mesh views
if sofa_mesh is not None:
    render_mesh_views(
        obj_path=sofa_mesh,
        save_prefix="sofa",
        distance=2.0,
        elevations=(10, 20, 30),
        azimuths=(-60, 0, 60)
    )
else:
    print("No mesh found for sofa")
# Out:
# /home/mad03633/Assign_6/graphics/lib/python3.10/site-packages/pytorch3d/io/obj_io.py:544: UserWarning: No mtl file provided
#   warnings.warn("No mtl file provided")
# Saved: /home/mad03633/Assign_6/renders/sofa_view1_elev10_azim-60.png
# Saved: /home/mad03633/Assign_6/renders/sofa_view2_elev20_azim0.png
# Saved: /home/mad03633/Assign_6/renders/sofa_view3_elev30_azim60.png

# %%
# Render motorcycle mesh views
if motorcycle_mesh is not None:
    render_mesh_views(
        obj_path=motorcycle_mesh,
        save_prefix="motorcycle",
        distance=2.0,
        elevations=(10, 20, 30),
        azimuths=(-60, 0, 60)
    )
else:
    print("No mesh found for motorcycle")
# Out:
# Saved: /home/mad03633/Assign_6/renders/motorcycle_view1_elev10_azim-60.png
# Saved: /home/mad03633/Assign_6/renders/motorcycle_view2_elev20_azim0.png
# Saved: /home/mad03633/Assign_6/renders/motorcycle_view3_elev30_azim60.png

# %%
motorcycle_predictions = (
    df_meshes[df_meshes["input_image"] == "motorcycle"]
    .sort_values("confidence_score", ascending=False)
    .reset_index(drop=True)
)

display(motorcycle_predictions[["predicted_class", "confidence_score", "mesh_file"]].head(10))
# Out:
#   predicted_class  confidence_score               mesh_file
# 0           chair             0.989  0_mesh_chair_0.989.obj
# 1             bed             0.749    1_mesh_bed_0.749.obj
# 2           table             0.724  2_mesh_table_0.724.obj
# 3           table             0.589  3_mesh_table_0.589.obj
# 4            sofa             0.436   4_mesh_sofa_0.436.obj
# 5            tool             0.415   5_mesh_tool_0.415.obj
# 6            tool             0.336   6_mesh_tool_0.336.obj
# 7            tool             0.305   7_mesh_tool_0.305.obj
# 8           chair             0.280  8_mesh_chair_0.280.obj
# 9            sofa             0.204   9_mesh_sofa_0.204.obj

# %%
top_motorcycle = motorcycle_predictions.head(10)

plt.figure(figsize=(10, 5))
plt.bar(
    top_motorcycle["predicted_class"] + " (" + top_motorcycle.index.astype(str) + ")",
    top_motorcycle["confidence_score"]
)
plt.xticks(rotation=45, ha="right")
plt.ylabel("Confidence score")
plt.title("Top predictions for out-of-distribution motorcycle image")
plt.tight_layout()
plt.show()
